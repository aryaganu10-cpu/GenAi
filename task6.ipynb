# %% [markdown]
# <a href="https://colab.research.google.com/github/aryaganu10-cpu/GenAi/blob/main/task6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from huggingface_hub import notebook_login

# This will prompt you to enter your Hugging Face token securely.
notebook_login()
import os

# Mount Google Drive to save cache persistently
from google.colab import drive
drive.mount('/content/drive')

# Set HF_HOME to a folder in your Google Drive
hf_cache_dir = '/content/drive/MyDrive/hf_cache'
os.makedirs(hf_cache_dir, exist_ok=True)
os.environ['HF_HOME'] = hf_cache_dir

print(f"Hugging Face cache directory set to: {os.environ['HF_HOME']}")
# Out:
# Mounted at /content/drive
# Hugging Face cache directory set to: /content/drive/MyDrive/hf_cache

# %%
import subprocess

# Clone the tabpfn-client repository
repo_url = "https://github.com/PriorLabs/tabpfn-client.git"
subprocess.run(["git", "clone", repo_url])

print(f"Repository {repo_url} cloned successfully.")
# Out:
# Repository https://github.com/PriorLabs/tabpfn-client.git cloned successfully.

# %%
import os

# Change current directory to tabpfn-client
os.chdir('tabpfn-client')
print(f"Current working directory: {os.getcwd()}")

# List contents of the directory to check for requirements.txt
print("Contents of tabpfn-client directory:")
print(os.listdir('.'))
# Out:
# Current working directory: /content/tabpfn-client
# Contents of tabpfn-client directory:
# ['.github', 'uv.lock', 'LICENSE', 'ruff.toml', 'tests', 'scripts', '.pre-commit-config.yaml', '.gitignore', '.git', 'pyproject.toml', 'README.md', 'src']

# %%
import subprocess

# Install the tabpfn-client package and its dependencies
subprocess.run(["pip", "install", "."])

print("tabpfn-client and its dependencies installed successfully.")
# Out:
# tabpfn-client and its dependencies installed successfully.

# %%
import os

# List contents of the scripts directory to find examples
print("Contents of tabpfn-client/scripts directory:")
print(os.listdir('scripts'))
# Out:
# Contents of tabpfn-client/scripts directory:
# ['gen_requirements.py']

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from tabpfn_client import TabPFNClassifier # Changed import to directly from tabpfn_client
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report

# 1. Load Dataset (UCI Credit Card Default)
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00350/default%20of%20credit%20card%20clients.xls"
df = pd.read_excel(url, header=1)

# Features and Target
X = df.drop(columns=['ID', 'default payment next month'])
y = df['default payment next month']

# 2. Split Data (25% Test Set)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# 3. Initialize Models
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
# Updated TabPFNClassifier initialization for tabpfn_client, removed 'device' and 'N_ensemble_configurations' arguments
tabpfn = TabPFNClassifier(model_path='v2.5_default', ignore_pretraining_limits=True)

# 4. Train and Predict
models = {"Random Forest": rf_model, "XGBoost": xgb_model, "TabPFN": tabpfn}
results = {}

for name, model in models.items():
    if name == "TabPFN":
        # Removed data subsetting for TabPFN
        model.fit(X_train, y_train)
    else:
        model.fit(X_train, y_train)

    preds = model.predict(X_test)
    probs = model.predict_proba(X_test)[:, 1]

    results[name] = {
        "Accuracy": accuracy_score(y_test, preds),
        "ROC-AUC": roc_auc_score(y_test, probs)
    }

# 5. Display Comparison
print(pd.DataFrame(results).T)
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [13:23:37] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ########  ########   ###  #########  #########       ###         #####     ########  ########
#      ###        ##   ###  ###   ###        ###       ###        ###  ###   ##   ###  ###
# ########  #######    ###  ###   ###  #######         ###        ########   ######    ########
# ###       ###   ##   ###  ###   ###  ###   ###       ###        ###  ###   ##   ###       ###
# ###       ###   ##   ###  #########  ###   ###       ########   ###  ###   ########  ########
# Thanks for being part of the journey
#   TabPFN is under active development, please help us improve and report any bugs/ideas you find.
#   Report issues: https://github.com/priorlabs/tabpfn-client/issues
#   Press Ctrl+C anytime to exit
# Opening browser for login. Please complete the login/registration process in your browser and return here.
#
#
# Could not open browser automatically. Falling back to command-line login...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# [1]     Create a TabPFN account
# [2]     Login to your TabPFN account
# [q]     Quit
# → Choose (1/2/q):
# 1
# Registration: 6 steps (about 2 minutes)
# Step 1/6 - Terms & Conditions
# By using TabPFN, you agree to the terms and conditions at ]8;id=808059;https://priorlabs.ai/general-terms-and-conditions\https://priorlabs.ai/general-terms-and-conditions]8;;\
# → I agree? (y/n):
# y
# Step 2/6 - Account Details
# Email:
# aryaganu10@gmail.com
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Step 3/6 - Create Password
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#   Requirements:
#     • Length(8)
#     • Uppercase(1)
#     • Numbers(1)
#     • Special(1)
# Password: ··········
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#   Requirements:
#     • Length(8)
#     • Uppercase(1)
#     • Numbers(1)
#     • Special(1)
#   Enter a password that meets all requirements.
# Password: ··········
# Confirm password: ··········
# Step 4/6 - Data Privacy
# I agree not to upload personal, confidential or sensitive data.
# → I agree (y/n):
# y
# Step 5/6 - Your Information
# This helps us personalize your experience
# First name:
# AG
# Last name:
# KG
# Step 6/6 - Help Us Serve You Better
# Just a few quick questions to get you started
# Where do you work?:
# →
# Warwick
# What is your current role?
# [a] Field practitioner
# [b] Researcher
# [c] Student
# [d] Other
# → Choose (a/b/c/d):
# c
# What do you want to use TabPFN for?:
# Example: Predicting customer churn in a SaaS application
# →
# Saas App
#   Could you add a bit more? We need at least 10 characters.
# →
# Saas applications
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# → Can we contact you via email for support? (y/n) :
# y
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Account created successfully!
#   Almost done! Check your email for a verification code.
# Email Verification
# Enter the verification code sent to your email.
# Type 'resend' to get a new code, or 'quit' to exit.
# Verification code:
# quit
# Verification cancelled.
#   You can verify your email later by logging in again.
# 00:02 Fitting... /
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-591/3472533636.py in <cell line: 0>()
#      30     if name == "TabPFN":
#      31         # Removed data subsetting for TabPFN
# ---> 32         model.fit(X_train, y_train)
#      33     else:
#      34         model.fit(X_train, y_train)
#
# /usr/local/lib/python3.12/dist-packages/tabpfn_client/estimator.py in fit(self, X, y, description)
#     252                     description=description,
#     253                 )
# --> 254             self.last_train_set_uid = run_task(fit_task, "Fitting", with_spinner=True)
#     255             self.last_train_X = X
#     256             self.last_train_y = y
#
# /usr/local/lib/python3.12/dist-packages/tabpfn_client/estimator.py in run_task(task, message, with_spinner)
#     640                 time.sleep(0.2)
#     641                 i += 1
# --> 642             result = future.result()
#     643         # Remove spinner, but keep elapsed time
#     644         sys.stdout.write(
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     447                     raise CancelledError()
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#     451                 self._condition.wait(timeout)
#
# /usr/lib/python3.12/concurrent/futures/_base.py in __get_result(self)
#     399         if self._exception:
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#     403                 # Break a reference cycle with the exception in self._exception
#
# /usr/lib/python3.12/concurrent/futures/thread.py in run(self)
#      57
#      58         try:
# ---> 59             result = self.fn(*self.args, **self.kwargs)
#      60         except BaseException as exc:
#      61             self.future.set_exception(exc)
#
# /usr/local/lib/python3.12/dist-packages/tabpfn_client/estimator.py in fit_task()
#     244
#     245             def fit_task() -> str:
# --> 246                 return InferenceClient.fit(
#     247                     X,
#     248                     y,
#
# /usr/local/lib/python3.12/dist-packages/tabpfn_client/service_wrapper.py in fit(cls, X, y, model_type, tabpfn_config, task, description)
#     256         description: str = "",
#     257     ) -> str:
# --> 258         return ServiceClient.fit(
#     259             X,
#     260             y,
#
# /usr/local/lib/python3.12/dist-packages/backoff/_sync.py in retry(*args, **kwargs)
#     103
#     104             try:
# --> 105                 ret = target(*args, **kwargs)
#     106             except exception as e:
#     107                 max_tries_exceeded = (tries == max_tries_value)
#
# /usr/local/lib/python3.12/dist-packages/tabpfn_client/client.py in fit(cls, X, y, model_type, tabpfn_config, task, description)
#     478             params=query_params,
#     479         ) as response:
# --> 480             cls._validate_response(response, "fit")
#     481             train_set_uid = None
#     482             for line in response.iter_lines():
#
# /usr/local/lib/python3.12/dist-packages/tabpfn_client/client.py in _validate_response(response, method_name, only_version_check)
#     763                 raise RetryableServerError(error_msg)
#     764             if load is not None:
# --> 765                 raise RuntimeError(f"Fail to call {method_name} with error: {load}")
#     766             logger.error(
#     767                 f"Fail to call {method_name}, response status: {response.status_code}"
#
# RuntimeError: Fail to call fit with error: {'code': 'auth.forbidden', 'detail': 'Dear TabPFN User, a verification email has been sent to your registered email address. Please use the token in it to verify your email address! Please Note: Without successful verification of the email, you will not be able to access the protected zone!', 'retryable': False, 'support': 'https://discord.com/invite/VJRuU3bSxt', 'docs': 'https://docs.priorlabs.ai', 'trace_id': '9260c92fd3de01fd2a5e8504129aa114'}
